# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %matplotlib inline

# %%
ticker_symbol = 'BTC-USD'

# Fetch Bitcoin data from Yahoo Finance
df = yf.download(ticker_symbol, start='2010-01-01', end='2024-07-31')

df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BTC-USD']: ModuleNotFoundError("No module named 'numpy.rec'")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Projects/bbbb/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:711, in __call__(self, obj)
#
# File ~/Projects/bbbb/myenv/lib/python3.12/site-packages/IPython/lib/pretty.py:419, in pretty(self, obj)
#
# File ~/Projects/bbbb/myenv/lib/python3.12/site-packages/IPython/lib/pretty.py:787, in _repr_pprint(obj, p, cycle)
#
# File ~/Projects/bbbb/myenv/lib/python3.12/site-packages/pandas/core/frame.py:1214, in __repr__(self)
#
# File ~/Projects/bbbb/myenv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in wrapper(*args, **kwargs)
#
# ...
